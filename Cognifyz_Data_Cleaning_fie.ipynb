# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Lenovo\Desktop\cognifyz dataset.csv")
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml? Gurme           208         ??stanbul
# 9547        5908749              Ceviz A??ac?           208         ??stanbul
# 9548        5915807                     Huqqa           208         ??stanbul
# 9549        5916112               A???k Kahve           208         ??stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ??stanbul
#
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml? Gurme           208         ??stanbul
# 9547        5908749              Ceviz A??ac?           208         ??stanbul
# 9548        5915807                     Huqqa           208         ??stanbul
# 9549        5916112               A???k Kahve           208         ??stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ??stanbul
#
# ...

# %%
df["Restaurant Name"]=df["Restaurant Name"].str.replace("?","").str.replace("_","")

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730                Naml Gurme           208         ??stanbul
# 9547        5908749                 Ceviz Aac           208         ??stanbul
# 9548        5915807                     Huqqa           208         ??stanbul
# 9549        5916112                  Ak Kahve           208         ??stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ??stanbul
#
# ...

# %%
df["City"].unique()
# Out:
# array(['Makati City', 'Mandaluyong City', 'Pasay City', 'Pasig City',
#        'Quezon City', 'San Juan City', 'Santa Rosa', 'Tagaytay City',
#        'Taguig City', 'Bras?_lia', 'Rio de Janeiro', 'S??o Paulo',
#        'Albany', 'Armidale', 'Athens', 'Augusta', 'Balingup',
#        'Beechworth', 'Boise', 'Cedar Rapids/Iowa City', 'Chatham-Kent',
#        'Clatskanie', 'Cochrane', 'Columbus', 'Consort', 'Dalton',
#        'Davenport', 'Des Moines', 'Dicky Beach', 'Dubuque',
#        'East Ballina', 'Fernley', 'Flaxton', 'Forrest', 'Gainesville',
#        'Hepburn Springs', 'Huskisson', 'Inverloch', 'Lakes Entrance',
#        'Lakeview', 'Lincoln', 'Lorn', 'Macedon', 'Macon', 'Mayfield',
#        'Mc Millan', 'Middleton Beach', 'Miller', 'Monroe', 'Montville',
#        'Ojo Caliente', 'Orlando', 'Palm Cove', 'Paynesville', 'Penola',
#        'Pensacola', 'Phillip Island', 'Pocatello', 'Potrero', 'Princeton',
#        'Rest of Hawaii', 'Savannah', 'Singapore', 'Sioux City',
# ...

# %%
df["City"]=df["City"].replace({'Bras?_lia': 'Brasília',
    'S??o Paulo': 'São Paulo',
    '??stanbul': 'İstanbul'})

# %%
df["City"].unique()
# Out:
# array(['Makati City', 'Mandaluyong City', 'Pasay City', 'Pasig City',
#        'Quezon City', 'San Juan City', 'Santa Rosa', 'Tagaytay City',
#        'Taguig City', 'Brasília', 'Rio de Janeiro', 'São Paulo', 'Albany',
#        'Armidale', 'Athens', 'Augusta', 'Balingup', 'Beechworth', 'Boise',
#        'Cedar Rapids/Iowa City', 'Chatham-Kent', 'Clatskanie', 'Cochrane',
#        'Columbus', 'Consort', 'Dalton', 'Davenport', 'Des Moines',
#        'Dicky Beach', 'Dubuque', 'East Ballina', 'Fernley', 'Flaxton',
#        'Forrest', 'Gainesville', 'Hepburn Springs', 'Huskisson',
#        'Inverloch', 'Lakes Entrance', 'Lakeview', 'Lincoln', 'Lorn',
#        'Macedon', 'Macon', 'Mayfield', 'Mc Millan', 'Middleton Beach',
#        'Miller', 'Monroe', 'Montville', 'Ojo Caliente', 'Orlando',
#        'Palm Cove', 'Paynesville', 'Penola', 'Pensacola',
#        'Phillip Island', 'Pocatello', 'Potrero', 'Princeton',
#        'Rest of Hawaii', 'Savannah', 'Singapore', 'Sioux City',
# ...

# %%
df["Address"].unique()
# Out:
# array(['Third Floor, Century City Mall, Kalayaan Avenue, Poblacion, Makati City',
#        'Little Tokyo, 2277 Chino Roces Avenue, Legaspi Village, Makati City',
#        'Edsa Shangri-La, 1 Garden Way, Ortigas, Mandaluyong City', ...,
#        'Kuru?_e??me Mahallesi, Muallim Naci Caddesi, No 56, Be??ikta??, ??stanbul',
#        'Kuru?_e??me Mahallesi, Muallim Naci Caddesi, No 64/B, Be??ikta??, ??stanbul',
#        'Cafea??a Mahallesi, Bademalt? Sokak, No 21/B, Kad?k?_y, ??stanbul'],
#       dtype=object)

# %%
df["Address"]= df["Address"].str.replace("?","").str.replace("_","")

# %%
df["Address"]
# Out:
# 0       Third Floor, Century City Mall, Kalayaan Avenu...
# 1       Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2       Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3       Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4       Third Floor, Mega Atrium, SM Megamall, Ortigas...
#                               ...
# 9546    Kemanke Karamustafa Paa Mahallesi, Rhtm Caddes...
# 9547    Kouyolu Mahallesi, Muhittin stnda Caddesi, No ...
# 9548    Kurueme Mahallesi, Muallim Naci Caddesi, No 56...
# 9549    Kurueme Mahallesi, Muallim Naci Caddesi, No 64...
# 9550    Cafeaa Mahallesi, Bademalt Sokak, No 21/B, Kad...
# Name: Address, Length: 9551, dtype: object

# %%
df["Locality"]= df["Locality"].str.replace("?","").str.replace("_","")

# %%
df["Locality Verbose"].unique()
# Out:
# array(['Century City Mall, Poblacion, Makati City, Makati City',
#        'Little Tokyo, Legaspi Village, Makati City, Makati City',
#        'Edsa Shangri-La, Ortigas, Mandaluyong City, Mandaluyong City',
#        ..., 'Ko??uyolu, ??stanbul', 'Kuru?_e??me, ??stanbul',
#        'Moda, ??stanbul'], dtype=object)

# %%
df["Locality Verbose"]= df["Locality Verbose"].str.replace("?","").str.replace("_","")

# %%
df["Longitude"].unique()
# Out:
# array([121.027535  , 121.014101  , 121.056831  , ...,  29.03464001,
#         29.036019  ,  29.02601603])

# %%
df["Cuisines"].unique()
# Out:
# array(['French, Japanese, Desserts', 'Japanese',
#        'Seafood, Asian, Filipino, Indian', ..., 'Burger, Izgara',
#        'World Cuisine, Patisserie, Cafe', 'Italian, World Cuisine'],
#       dtype=object)

# %%
df["Cuisines"].str.contains("?", regex=False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# Name: Cuisines, Length: 9551, dtype: object

# %%
df["Cuisines"]= df["Cuisines"].str.replace("?","").str.replace("_","")

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df['Currency'].unique()
# Out:
# array(['Botswana Pula(P)', 'Brazilian Real(R$)', 'Dollar($)',
#        'Emirati Diram(AED)', 'Indian Rupees(Rs.)',
#        'Indonesian Rupiah(IDR)', 'NewZealand($)', 'Pounds(??)',
#        'Qatari Rial(QR)', 'Rand(R)', 'Sri Lankan Rupee(LKR)',
#        'Turkish Lira(TL)'], dtype=object)

# %%
df['Currency'] = df['Currency'].str.replace('Pounds(??)', 'Pounds(£)', regex=False)

# %%
df['Votes'].unique()
# Out:
# array([ 314,  591,  270, ...,  788, 1034,  901], dtype=int64)

# %%
df.to_excel('cleaned_data_cognifyz.xlsx', index=False)
from IPython.display import FileLink

# Create a clickable link to download the file
FileLink('cleaned_data_cognifyz.xlsx')
# Out:
# C:\Users\Lenovo\cleaned_data_cognifyz.xlsx
